# %%
from PIL import Image
dog = Image.open('dog.jpg')
display(dog)
dog.height
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=420x550 at 0x7FA5CBCB96A0>
# 550

# %%
import cv2
import matplotlib.pyplot as plt

# %%
dog = cv2.imread('dog.jpg')
dog_rgb = cv2.cvtColor(dog, cv2.COLOR_BGR2RGB)

# %%
dog_r = cv2.resize(dog_rgb, (500, 500))
dog_r.shape
plt.imshow(dog_r)
